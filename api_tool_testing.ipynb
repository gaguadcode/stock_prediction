# %%
# Import required modules
from langchain_ollama import OllamaLLM
from langgraph.prebuilt import create_react_agent
from langchain.schema import SystemMessage, HumanMessage
from langchain_community.agent_toolkits.openapi.toolkit import RequestsToolkit
from langchain_community.utilities.requests import TextRequestsWrapper
from app.utils.config import config  # Import the pedantic-based config object



# Fetch the configuration variables from the config object
base_url = config.ALPHAVANTAGE_BASE_URL
api_key = config.ALPHAVANTAGE_API_KEY

# Load API documentation from the `api_doc.txt` file
with open("api_doc.txt", "r") as file:
    api_spec = file.read()

# Define the system prompt with dynamic variables
system_prompt_agente_agnostico = f"""
Tienes acceso a una API para responder a las consultas que te hagan.
- Se te proveerá la documentación de la API.
- Debes utilizar las herramientas proporcionadas para consultar la API y responder a la pregunta del usuario.
Aquí está la documentación de la API:

Documentación de la API:
{api_spec}

Detalles adicionales:
- Base URL: {base_url}
- API Key: {api_key}

Cuando necesites hacer una solicitud GET, asegúrate de incluir el API Key como parte de los parámetros.
"""

# Initialize the language model (LLM)
llm = OllamaLLM(model="mistral")  # Replace with the desired model
slm = OllamaLLM(model="smollm")

# Create tools for interacting with the API (replace this with actual tools for your API)

toolkit = RequestsToolkit(
    requests_wrapper=TextRequestsWrapper(headers={}),
    allow_dangerous_requests=True,
)

tools = toolkit.get_tools()

tools

# Initialize the agent
agente_agnostico = create_react_agent(
    model=llm,
    tools=tools,
    state_modifier=SystemMessage(content=system_prompt_agente_agnostico),
)

# Define the user question
user_question = "quiero saber el precio del barril de brent (BRENT) de manera mensual para enero de 2025"

# Query the agent and stream responses
print("=== Prueba del Agente Agnóstico ===")
for chunk in agente_agnostico.stream(
    {
        "messages": [
            SystemMessage(content=system_prompt_agente_agnostico),
            HumanMessage(content=user_question),
        ]
    }
):
    print(chunk)
    print("----")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 52
#      49 tools
#      51 # Initialize the agent
# ---> 52 agente_agnostico = create_react_agent(
#      53     model=llm,
#      54     tools=tools,
#      55     state_modifier=SystemMessage(content=system_prompt_agente_agnostico),
#      56 )
#      58 # Define the user question
#      59 user_question = "quiero saber el precio del barril de brent (BRENT) de manera mensual para enero de 2025"
#
# File ~/Desktop/personal_projects/stock_prediction_app/price/lib/python3.11/site-packages/langgraph/_api/deprecation.py:80, in deprecated_parameter.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      72 if arg_name in kwargs:
#      73     warnings.warn(
#      74         f"Parameter '{arg_name}' in function '{func.__name__}' is "
# ...

# %%
from langgraph.graph import StateGraph, START, END
from typing_extensions import TypedDict
from typing import Dict
from app.utils.logger import get_logger
from app.utils.datatypes import (
    UserInputString,
    EntityExtractOutput,
    DataFetchOutput,
    FinalPredictionState,
    StockPredictionRequest,
    StockPredictionOutput
)
from app.graph_nodes.stock.stock_extractor_agent import StockDataExtractor
from app.graph_nodes.stock.stock_fetch_data import HistoricalDataFetcher
from app.graph_nodes.stock.model_training import StockDataTrainer
from app.graph_nodes.stock.prediction import StockPredictor


# **✅ Initialize LangGraph workflow**
graph = StateGraph(UserInputString)

# **✅ Logger setup**
logger = get_logger("StockPredictionWorkflow")

# **✅ Step 1: Entity Extraction Node**
def entity_extraction_node(state: UserInputString) -> EntityExtractOutput:
    logger.info("Running Entity Extraction Node...")
    extractor = StockDataExtractor()
    extracted_data = extractor.process_input(state)

    return extracted_data

graph.add_node("entity_extraction", entity_extraction_node)

# **✅ Step 2: Data Fetching Node**
def data_fetching_node(state: EntityExtractOutput) -> DataFetchOutput:
    logger.info("Running Data Fetching Node...")
    fetcher = HistoricalDataFetcher()
    data_fetch_output = fetcher.fetch_and_store_historical_data(
        EntityExtractOutput(**state["entity_extract"])
    )
    return data_fetch_output

graph.add_node("data_fetching", data_fetching_node)
'''
# **✅ Step 3: Training Node**
def training_node(state: StockPredictionState) -> Dict:
    logger.info("Running Training Node...")
    trainer = StockDataTrainer()
    final_state = trainer.execute_training(DataFetchOutput(**state["data_fetch_output"]))

    return {"final_state": final_state}

graph.add_node("training", training_node)

# **✅ Step 4: Prediction Node**
def prediction_node(state: StockPredictionState) -> Dict:
    logger.info("Running Prediction Node...")
    predictor = StockPredictor(FinalPredictionState(**state["final_state"]))

    stock_request = state["final_state"]["entity_extract"]["entity_extract"]["stock_prediction"]
    stock_request_obj = StockPredictionRequest(**stock_request)

    prediction_output = predictor.make_predictions(stock_request_obj)

    return {"prediction": prediction_output}

graph.add_node("prediction", prediction_node)
'''
# **✅ Define Execution Order**
graph.add_edge(START, "entity_extraction")
graph.add_edge("entity_extraction", "data_fetching")
#graph.add_edge("data_fetching", "training")
#graph.add_edge("training", "prediction")
#graph.add_edge("prediction", END)

# **✅ Compile the Graph**
workflow = graph.compile()

# **✅ Running the Workflow**
state = workflow.invoke({
    "user_input": "quiero saber el precio de IBM de manera mensual para enero de 2025"
})

print(state)  # Output the final workflow state
# Out:
# 2025-02-08 20:05:37,518 - StockPredictionWorkflow - INFO - Running Entity Extraction Node...
# 2025-02-08 20:05:37,518 - StockPredictionWorkflow - INFO - Running Entity Extraction Node...
# 2025-02-08 20:05:37,518 - StockPredictionWorkflow - INFO - Running Entity Extraction Node...
# 2025-02-08 20:05:37,518 - StockPredictionWorkflow - INFO - Running Entity Extraction Node...
# 2025-02-08 20:05:37,518 - StockPredictionWorkflow - INFO - Running Entity Extraction Node...
# 2025-02-08 20:05:37,520 - StockDataExtractor - INFO - Initializing StockDataExtractor with model 'mistral:7b'
# 2025-02-08 20:05:37,520 - StockDataExtractor - INFO - Initializing StockDataExtractor with model 'mistral:7b'
# 2025-02-08 20:05:37,520 - StockDataExtractor - INFO - Initializing StockDataExtractor with model 'mistral:7b'
# 2025-02-08 20:05:37,520 - StockDataExtractor - INFO - Initializing StockDataExtractor with model 'mistral:7b'
# ...

# %% [markdown]
# ## Image OCR

# %%
# Load environment variables
import os
import base64
import requests
from app.utils.config import config

# Load API key from .env file

MISTRAL_API_KEY = config.MISTRAL_API_KEY
print(MISTRAL_API_KEY)
# Ensure API key is set
if not MISTRAL_API_KEY:
    raise ValueError("❌ MISTRAL_API_KEY is missing. Set it in the .env file.")
# Out:
# SAS1Qajk73kbPVHyebEcozgSHx7PCiUf

# %%
def encode_image_to_base64(image_path: str) -> str:
    """
    Converts an image file to a Base64-encoded string.

    Args:
        image_path (str): Path to the image file.

    Returns:
        str: Base64-encoded string of the image.
    """
    try:
        with open(image_path, "rb") as image_file:
            base64_string = base64.b64encode(image_file.read()).decode("utf-8")
        return base64_string
    except Exception as e:
        raise ValueError(f"❌ Failed to encode image to Base64: {e}")

# %%
import os
from mistralai import Mistral

# Initialize Mistral client

client = Mistral(api_key=MISTRAL_API_KEY)

def perform_ocr(base64_image: str, model_id: str = "mistral-ocr-1") -> str:
    """
    Sends a Base64-encoded image to Mistral's OCR model for text extraction.

    Args:
        base64_image (str): Base64-encoded image string.
        model_id (str): The Mistral OCR model ID (default: 'mistral-ocr-1').

    Returns:
        str: Extracted text from the image.
    """
    # Prepare the document payload
    document = {
        "image_base64": base64_image
    }

    # Perform OCR
    response = client.ocr(model=model_id, document=document)

    # Extract text from response
    extracted_text = response.get("text", "")
    return extracted_text

# %%
# 🔹 Provide the image file path here
image_path = "aapl-1.5-trillion-market-cap.jpeg"  # Replace with your actual image file path

# Encode image to Base64
base64_image = encode_image_to_base64(image_path)

# Perform OCR
extracted_text = perform_ocr(base64_image)

# Output the extracted text
print("Extracted Text:", extracted_text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       5 base64_image = encode_image_to_base64(image_path)
#       7 # Perform OCR
# ----> 8 extracted_text = perform_ocr(base64_image)
#      10 # Output the extracted text
#      11 print("Extracted Text:", extracted_text)
#
# Cell In[12], line 25, in perform_ocr(base64_image, model_id)
#      20 document = {
#      21     "image_base64": base64_image
#      22 }
#      24 # Perform OCR
# ---> 25 response = client.ocr(model=model_id, document=document)
#      27 # Extract text from response
#      28 extracted_text = response.get("text", "")
#
# TypeError: 'Ocr' object is not callable

# %%
import os
import base64
import logging
from mistralai import Mistral
from app.utils.config import config
# Configure Logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

class MistralOCR:
    """
    A class to perform OCR using Mistral AI on Base64-encoded images.
    """

    def __init__(self):
        """
        Initializes the Mistral client with the API key.
        """
        if not MISTRAL_API_KEY:
            raise ValueError("❌ MISTRAL_API_KEY is missing. Please set it in config.py or as an environment variable.")

        self.client = Mistral(api_key=MISTRAL_API_KEY)
        self.model_name = "mistral-ocr-latest"  # Model for OCR processing

    def encode_image_to_base64(self, image_path: str) -> str:
        """
        Converts an image file to a Base64-encoded string.
        
        Args:
            image_path (str): Path to the image file.

        Returns:
            str: Base64-encoded string of the image.
        """
        try:
            with open(image_path, "rb") as image_file:
                encoded_string = base64.b64encode(image_file.read()).decode("utf-8")
                logger.info(f"📸 Image successfully encoded to Base64: {image_path}")
                return encoded_string
        except FileNotFoundError:
            logger.error(f"❌ Error: The file '{image_path}' was not found.")
            return None
        except Exception as e:
            logger.error(f"❌ Error encoding image: {e}")
            return None

    def perform_ocr(self, base64_image: str) -> str:
        """
        Sends a Base64-encoded image to Mistral's OCR model for text extraction.

        Args:
            base64_image (str): Base64-encoded image string.

        Returns:
            str: Extracted text from the image.
        """
        if not base64_image:
            logger.error("❌ No valid Base64 image provided for OCR processing.")
            return None

        try:
            logger.info("🔍 Sending image to Mistral OCR API...")

            # Perform OCR request
            response = self.client.ocr.process(
                model=self.model_name,
                document={
                    "type": "image_url",
                    "image_url": f"data:image/jpeg;base64,{base64_image}"  # Format as Data URL
                }
            )

            # Extract and return text
            extracted_text = response.get("text", "")
            logger.info("✅ OCR processing complete.")
            return extracted_text

        except Exception as e:
            logger.error(f"❌ OCR processing failed: {e}")
            return None

# Example Usage
if __name__ == "__main__":
    # Path to the image file
    image_path = "aapl-1.5-trillion-market-cap.jpeg" 

    # Initialize OCR handler
    ocr_handler = MistralOCR()

    # Convert image to Base64
    base64_image = ocr_handler.encode_image_to_base64(image_path)

    # Perform OCR
    extracted_text = ocr_handler.perform_ocr(base64_image)

    # Output the extracted text
    if extracted_text:
        print("📜 Extracted Text:\n", extracted_text)
    else:
        print("❌ No text extracted.")
# Out:
# INFO:__main__:📸 Image successfully encoded to Base64: aapl-1.5-trillion-market-cap.jpeg
# INFO:__main__:🔍 Sending image to Mistral OCR API...
# INFO:httpx:HTTP Request: POST https://api.mistral.ai/v1/ocr "HTTP/1.1 200 OK"
# ERROR:__main__:❌ OCR processing failed: 'OCRResponse' object has no attribute 'get'
# ❌ No text extracted.

# %%
import base64
import mimetypes
from mistralai import Mistral as MistralClient
from typing import Dict, Any, Optional, Union
import os
from app.utils.config import config



class MistralOcrClient:
    """
    A client for interacting with the Mistral OCR API.
    """
    
    def __init__(self, api_key: Optional[str] = None):
        """
        Initialize the Mistral OCR client.
        
        Args:
            api_key: Mistral API key. If not provided, will look for MISTRAL_API_KEY in environment variables.
        """
        self.api_key = api_key or config.MISTRAL_API_KEY
        if not self.api_key:
            raise ValueError("API key must be provided either directly or via MISTRAL_API_KEY environment variable")
        
        self.client = MistralClient(api_key=self.api_key)
    
    def load_image(self, image_path: str) -> str:
        """
        Load an image from a file path and convert it to a base64-encoded data URL.
        
        Args:
            image_path: Path to the image file
            
        Returns:
            A base64-encoded data URL string
        """
        mime_type, _ = mimetypes.guess_type(image_path)
        if not mime_type:
            # Default to JPEG if mime type cannot be determined
            mime_type = "image/jpeg"
            
        with open(image_path, "rb") as image_file:
            image_data = image_file.read()
            
        base64_encoded = base64.b64encode(image_data).decode('utf-8')
        base64_url = f"data:{mime_type};base64,{base64_encoded}"
        return base64_url
    
    def process_image(self, 
                     image_path: str, 
                     model: str = "mistral-ocr-latest",
                     options: Optional[Dict[str, Any]] = None) -> Dict[str, Any]:
        """
        Process an image through the Mistral OCR API.
        
        Args:
            image_path: Path to the image file
            model: OCR model to use (default: "mistral-ocr-latest")
            options: Additional OCR processing options
            
        Returns:
            OCR API response as a dictionary
        """
        image_url = self.load_image(image_path)
        
        ocr_response = self.client.ocr.process(
            model=model,
            document={
                "type": "image_url",
                "image_url": image_url,
            },
            options=options
        )
        
        return ocr_response
    
    def process_from_url(self, 
                        image_url: str, 
                        model: str = "mistral-ocr-latest",
                        options: Optional[Dict[str, Any]] = None) -> Dict[str, Any]:
        """
        Process an image from a URL through the Mistral OCR API.
        
        Args:
            image_url: URL of the image (can be a web URL or base64 data URL)
            model: OCR model to use (default: "mistral-ocr-latest")
            options: Additional OCR processing options
            
        Returns:
            OCR API response as a dictionary
        """
        ocr_response = self.client.ocr.process(
            model=model,
            document={
                "type": "image_url",
                "image_url": image_url,
            },
            options=options
        )
        
        return ocr_response
    
    def extract_text(self, ocr_response: Dict[str, Any]) -> str:
        """
        Extract plain text from an OCR response.
        
        Args:
            ocr_response: Response from the OCR API
            
        Returns:
            Extracted text as a string
        """
        text = ""
        
        if "text" in ocr_response:
            text = ocr_response["text"]
        
        return text

# %%
import os
from pathlib import Path
from app.utils.config import config

 # Assuming you saved the previous code as mistral_ocr_client.py

def extract_text_from_local_image(image_path):
    """
    Extract text from a local image using Mistral OCR API.
    
    Args:
        image_path: Path to the local image file
        
    Returns:
        Extracted text as a string
    """
    # Initialize the client
    # You can either set MISTRAL_API_KEY environment variable or pass it directly
    api_key = config.MISTRAL_API_KEY
    ocr_client = MistralOcrClient(api_key=api_key)
    
    # Ensure the image path exists
    image_path = Path(image_path)
    if not image_path.exists():
        raise FileNotFoundError(f"Image file not found: {image_path}")
    
    # Process the image
    try:
        result = ocr_client.process_image(str(image_path))
        
        # Extract the text
        extracted_text = ocr_client.extract_text(result)
        
        return extracted_text
    except Exception as e:
        print(f"Error processing image: {e}")
        return None

if __name__ == "__main__":
    # Example usage
    image_path = "aapl-1.5-trillion-market-cap.jpeg"  # Replace with your actual image path
    
    extracted_text = extract_text_from_local_image(image_path)
    
    if extracted_text:
        print("Extracted Text:")
        print("-" * 40)
        print(extracted_text)
        print("-" * 40)
        
        # Optionally save the extracted text to a file
        output_file = Path(image_path).with_suffix(".txt")
        with open(output_file, "w", encoding="utf-8") as f:
            f.write(extracted_text)
        print(f"Text saved to: {output_file}")
# Out:
# Error processing image: Ocr.process() got an unexpected keyword argument 'options'

# %%
import base64
import requests
import os
from mistralai import Mistral
from app.utils.config import config

def encode_image(image_path):
    """Encode the image to base64."""
    try:
        with open(image_path, "rb") as image_file:
            return base64.b64encode(image_file.read()).decode('utf-8')
    except FileNotFoundError:
        print(f"Error: The file {image_path} was not found.")
        return None
    except Exception as e:  # Added general exception handling
        print(f"Error: {e}")
        return None

# Path to your image
image_path = "aapl-1.5-trillion-market-cap.jpeg"

# Getting the base64 string
base64_image = encode_image(image_path)

api_key = config.MISTRAL_API_KEY
client = Mistral(api_key=api_key)

ocr_response = client.ocr.process(
    model="mistral-ocr-latest",
    document={
        "type": "image_url",
        "image_url": f"data:image/jpeg;base64,{base64_image}" 
    }
)
# Out:
# INFO:httpx:HTTP Request: POST https://api.mistral.ai/v1/ocr "HTTP/1.1 200 OK"

# %%
print(ocr_response)
# Out:
# pages=[OCRPageObject(index=0, markdown='# AAPL \n\nApple Inc.\n$352.22+8.23$\n\n| 1D | 1 W | 1 M | 3 M | 6 M | 1 Y | 2 Y | 5 Y | 10 Y | ALL |\n| :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: |\n| ![img-0.jpeg](img-0.jpeg) | ![img-1.jpeg](img-1.jpeg) | ![img-2.jpeg](img-2.jpeg) | ![img-3.jpeg](img-3.jpeg) | ![img-4.jpeg](img-4.jpeg) | ![img-5.jpeg](img-5.jpeg) | ![img-6.jpeg](img-6.jpeg) | ![img-7.jpeg](img-7.jpeg) | ![img-8.jpeg](img-8.jpeg) | ![img-9.jpeg](img-9.jpeg) |\n| 11 |  | 18 |  | 26 |  |  | 2 |  | 9 |\n| Open | 347.90 | Vol | 19.52M | 52W H | 352.84 | Yield | 0.95\\% | More Data from Yahoo |  |\n| High | 352.84 | P/E | 27.66 | 52W L | 190.30 | Beta | 1.17 |  |  |\n| Low | 346.09 | Mkt Cap | 1.527T | Avg Vol | 44.97M | EPS | 12.73 |  |  |', images=[OCRImageObject(id='img-0.jpeg', top_left_x=42, top_left_y=324, bottom_right_x=264, bottom_right_y=432, image_base64=None), OCRImageObject(id='img-1.jpeg', top_left_x=266, top_left_y=324, bottom_right_x=407, b
# ...

# %%
import json
import pprint
from typing import Dict, Any, List, Optional

def pretty_print_ocr_response(ocr_response, show_markdown=True, show_images=False, indent=2):
    """
    Pretty print an OCR response from Mistral OCR API.
    
    Args:
        ocr_response: The response from the OCR API
        show_markdown: Whether to display the extracted markdown content
        show_images: Whether to display information about detected images
        indent: Indentation level for pretty printing
    """
    # Extract basic information
    print("="*80)
    print(f"OCR RESPONSE SUMMARY")
    print("="*80)
    
    # Model information
    print(f"Model: {ocr_response.model}")
    
    # Usage information
    if hasattr(ocr_response, 'usage_info'):
        print(f"Pages processed: {ocr_response.usage_info.pages_processed}")
    
    # Process pages
    print(f"\nTotal pages: {len(ocr_response.pages)}")
    
    for i, page in enumerate(ocr_response.pages):
        print("\n" + "-"*80)
        print(f"PAGE {i+1}")
        print("-"*80)
        
        # Page dimensions
        if hasattr(page, 'dimensions'):
            dims = page.dimensions
            print(f"Dimensions: {dims.width}x{dims.height} pixels at {dims.dpi} DPI")
        
        # Extracted text
        if show_markdown and page.markdown:
            print("\nEXTRACTED CONTENT (MARKDOWN):")
            print("-"*40)
            print(page.markdown)
            print("-"*40)
        
        # Image information
        if show_images and hasattr(page, 'images') and page.images:
            print("\nDETECTED IMAGES:")
            print("-"*40)
            for j, img in enumerate(page.images):
                print(f"Image {j+1}: ID={img.id}")
                print(f"  Position: ({img.top_left_x}, {img.top_left_y}) to ({img.bottom_right_x}, {img.bottom_right_y})")
            print("-"*40)
    
    print("\n" + "="*80)

def display_extracted_data(ocr_response):
    """
    Display structured data extracted from the OCR response.
    Particularly useful for financial data like in your example.
    """
    # Let's extract the financial data from your specific example
    if not ocr_response.pages or not ocr_response.pages[0].markdown:
        print("No content to parse.")
        return
    
    markdown = ocr_response.pages[0].markdown
    
    # Extract ticker and company name
    lines = markdown.split('\n')
    ticker = ""
    company = ""
    
    for i, line in enumerate(lines):
        if line.startswith('# '):
            ticker = line.replace('# ', '').strip()
            if i+1 < len(lines):
                company = lines[i+1].strip()
            break
    
    # Extract price
    price = ""
    price_change = ""
    for line in lines:
        if '$' in line and '+' in line:
            parts = line.split('+')
            if len(parts) >= 2:
                price = parts[0].strip()
                price_change = '+' + parts[1].strip()
            break
    
    # Extract key statistics (we'll look for common patterns in financial data)
    stats = {}
    for line in lines:
        if '|' in line:
            cells = [cell.strip() for cell in line.split('|')]
            if len(cells) >= 3:
                # Look for key-value pairs in table cells
                for i in range(0, len(cells)-1, 2):
                    key = cells[i].strip()
                    if i+1 < len(cells):
                        value = cells[i+1].strip()
                        if key and value and key != ":" and not key.startswith('--'):
                            stats[key] = value
    
    # Display the extracted financial data in a nicer format
    print("\n" + "="*50)
    print(f"FINANCIAL DATA: {ticker}")
    print("="*50)
    print(f"Company: {company}")
    print(f"Price: {price} ({price_change})")
    print("\nKEY STATISTICS:")
    print("-"*30)
    
    # Format the stats in columns
    formatted_stats = []
    row = []
    for key, value in stats.items():
        if len(row) < 2:
            row.append(f"{key}: {value}")
        else:
            formatted_stats.append(row)
            row = [f"{key}: {value}"]
    
    if row:
        formatted_stats.append(row)
        
    for row in formatted_stats:
        print("  ".join(f"{item:<25}" for item in row))
    
    print("="*50)

# Example usage
def display_ocr_results(ocr_response):
    """Wrapper function to display OCR results in multiple formats"""
    # Pretty print basic info
    pretty_print_ocr_response(ocr_response)
    
    # Display structured financial data (for your specific case)
    display_extracted_data(ocr_response)

# %%
display_ocr_results(ocr_response)
# Out:
# ...
# OCR RESPONSE SUMMARY
# ...
# Model: mistral-ocr-2503-completion
# Pages processed: 1
#
# Total pages: 1
#
# --------------------------------------------------------------------------------
# PAGE 1
# --------------------------------------------------------------------------------
# Dimensions: 1643x924 pixels at 200 DPI
#
# EXTRACTED CONTENT (MARKDOWN):
# ----------------------------------------
# # AAPL
#
# Apple Inc.
# $352.22+8.23$
#
# | 1D | 1 W | 1 M | 3 M | 6 M | 1 Y | 2 Y | 5 Y | 10 Y | ALL |
# | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: |
# | ![img-0.jpeg](img-0.jpeg) | ![img-1.jpeg](img-1.jpeg) | ![img-2.jpeg](img-2.jpeg) | ![img-3.jpeg](img-3.jpeg) | ![img-4.jpeg](img-4.jpeg) | ![img-5.jpeg](img-5.jpeg) | ![img-6.jpeg](img-6.jpeg) | ![img-7.jpeg](img-7.jpeg) | ![img-8.jpeg](img-8.jpeg) | ![img-9.jpeg](img-9.jpeg) |
# | 11 |  | 18 |  | 26 |  |  | 2 |  | 9 |
# | Open | 347.90 | Vol | 19.52M | 52W H | 352.84 | Yield | 0.95\% | More Data from Yahoo |  |
# ...

# %%
from app.graph_nodes.imageOCR.image_to_text import OcrProcessor

# Path to your image
image_path = "aapl-1.5-trillion-market-cap.jpeg"

# Initialize the OCR processor
ocr = OcrProcessor()

# Process the image
ocr_response = ocr.process_image(image_path)

# Print the extracted text
print("=== OCR Results ===")
print(ocr.extract_markdown(ocr_response))

# Save to markdown file
output_path = image_path.replace('.jpeg', '.md')
ocr.save_markdown_to_file(ocr.format_ocr_response_as_markdown(ocr_response), output_path)
print(f"Results saved to: {output_path}")
# Out:
# INFO:httpx:HTTP Request: POST https://api.mistral.ai/v1/ocr "HTTP/1.1 200 OK"
# === OCR Results ===
# # AAPL
#
# Apple Inc.
# $352.22+8.23$
#
# | 1D | 1 W | 1 M | 3 M | 6 M | 1 Y | 2 Y | 5 Y | 10 Y | ALL |
# | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: | :--: |
# | ![img-0.jpeg](img-0.jpeg) | ![img-1.jpeg](img-1.jpeg) | ![img-2.jpeg](img-2.jpeg) | ![img-3.jpeg](img-3.jpeg) | ![img-4.jpeg](img-4.jpeg) | ![img-5.jpeg](img-5.jpeg) | ![img-6.jpeg](img-6.jpeg) | ![img-7.jpeg](img-7.jpeg) | ![img-8.jpeg](img-8.jpeg) | ![img-9.jpeg](img-9.jpeg) |
# | 11 |  | 18 |  | 26 |  |  | 2 |  | 9 |
# | Open | 347.90 | Vol | 19.52M | 52W H | 352.84 | Yield | 0.95\% | More Data from Yahoo |  |
# | High | 352.84 | P/E | 27.66 | 52W L | 190.30 | Beta | 1.17 |  |  |
# | Low | 346.09 | Mkt Cap | 1.527T | Avg Vol | 44.97M | EPS | 12.73 |  |  |
# Results saved to: aapl-1.5-trillion-market-cap.md
